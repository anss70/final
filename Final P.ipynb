# %%
import numpy as np
import matplotlib.pyplot as plt
from prettytable import PrettyTable as tp

# %%
 
myTable = tp(["Student Name", "Class", "Section", "Percentage" , 'Gender'])
 
myTable.add_row(["Anas", "s", "B", "91.2 %",'Boy'])
myTable.add_row(["Omar", "a", "C", "63.5 %",'Boy'])
myTable.add_row(["Amgad", "d", "A", "90.3 %",'Girl'])
myTable.add_row(["Amal", "e", "D", "92.7 %",'Girl'])
myTable.add_row(["Ahmad", "f", "A", "98.2 %",'Boy'])
myTable.add_row(["Slamn", "g", "B", "88.1 %",'Boy'])
myTable.add_row(["Emad", "X", "B", "95.0 %",'Boy'])
myTable.add_row(['Lmeai','k','B','87.2 %','Girl'])
myTable.add_row(['Dlal','m','A','82.9 %','Girl'])
 
print(myTable)
# Out:
# +--------------+-------+---------+------------+--------+
# | Student Name | Class | Section | Percentage | Gender |
# +--------------+-------+---------+------------+--------+
# |     Anas     |   s   |    B    |   91.2 %   |  Boy   |
# |     Omar     |   a   |    C    |   63.5 %   |  Boy   |
# |    Amgad     |   d   |    A    |   90.3 %   |  Girl  |
# |     Amal     |   e   |    D    |   92.7 %   |  Girl  |
# |    Ahmad     |   f   |    A    |   98.2 %   |  Boy   |
# |    Slamn     |   g   |    B    |   88.1 %   |  Boy   |
# |     Emad     |   X   |    B    |   95.0 %   |  Boy   |
# |    Lmeai     |   k   |    B    |   87.2 %   |  Girl  |
# |     Dlal     |   m   |    A    |   82.9 %   |  Girl  |
# +--------------+-------+---------+------------+--------+

# %%
data = (
    
[["Class", "Section", "Percentage" , 'Gender']] 
+ [["Anas", "s", "B", "91.2 %",'Boy']] 
+ [["Omar", "a", "C", "63.5 %",'Boy']] 
+ [["Amgad", "d", "A", "90.3 %",'Girl']]
+ [["Amal", "e", "D", "92.7 %",'Girl']]
+ [["Ahmad", "f", "A", "98.2 %",'Boy']]
+ [["Slamn", "g", "B", "88.1 %",'Boy']]
+ [["Emad", "X", "B", "95.0 %",'Boy']]
+ [['Lmeai','k','B','87.2 %','Girl']]
+ [['Dlal','m','A','82.9 %','Girl']]

 )
column_headers = data[0]
row_headers = [row[0] for row in data[1:]]
cell_text = [row[1:] for row in data[1:]]

fig, ax1 = plt.subplots(figsize=(8, 2 + 8 / 2))

rcolors = np.full(len(row_headers), 'papayawhip')                          
ccolors = np.full(len(column_headers), 'gray')

table = ax1.table(cellText=cell_text,
                  cellLoc='center',
                  rowLabels=row_headers,
                  rowColours=rcolors,
                  rowLoc='center',
                  colColours=ccolors,
                  colLabels=column_headers,
                  loc='center')
table.scale(2, 2)
table.set_fontsize(20)
ax1.axis('off')

title = "Students' grades"
subtitle = "Anas School"
ax1.set_title(f'{title}\n({subtitle})', weight='bold', size=20, color='gold')

plt.savefig("demo_table.png", dpi=200, bbox_inches='tight')

# %%
Percentage = [91.2,63.5,90.3,92.7,98.2,88.1,95.0,87.2,82.9]

range = (50, 100)
bins = 10

plt.hist(ages, bins, range, color = 'gold',							
		histtype = 'bar', rwidth = 0.7)                       


plt.xlabel('Percentage')

plt.ylabel('No. of student')

plt.title('Percentage')

plt.show()
